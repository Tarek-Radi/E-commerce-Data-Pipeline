# %%
import pandas as pd
import csv

df_customer = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_customers_dataset.csv")
df_order = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_orders_dataset.csv")
df_order_items = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_order_items_dataset.csv")
df_gl = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_geolocation_dataset.csv")
df_payment = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_order_payments_dataset.csv")
df_reviews = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_order_reviews_dataset.csv")
df_products = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_products_dataset.csv")
df_sellers = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\olist_sellers_dataset.csv")
df_product_category = pd.read_csv(r"E:\Data Engineering Projects\Brazilian E-Commerce Project\datasets\product_category_name_translation.csv")

# %%
df_customer.head()

# %%
df_customer['customer_id'].nunique(), len(df_customer) , df_customer['customer_unique_id'].nunique()  #All of cutomer_id is unique

# %%
df_order.head()

# %%
df_order_items.head()

# %%
df_customer.info()

# %%
df_order.info()  #Dim  but Supporting Fact

# %%
df_order_items.info()  #Fact  ---> Price is Grain

# %%
df_order_items['price'].sum()

# %%
df_order_items['price'].mean()

# %%
df_order['order_id'].nunique(), len(df_order) , df_order['customer_id'].nunique()

# %%
df_gl.head()

# %%
df_payment.info()  #Dim

# %%
df_reviews.info() #Dim but Supporting Fact

# %%
df_products.info()   #Dim

# %%
df_products.head()

# %%
df_sellers.info() #Dim

# %%
df_product_category.info() #Dim
